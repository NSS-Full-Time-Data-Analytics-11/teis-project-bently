# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import statsmodels.api as sm

# %%
teis_df = pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/projects/teis-project-bently/data/teis.csv', dtype = {"Child ID" : object, "Cognitive T-Score" : object})

# %%
teis_df=teis_df.drop(columns=['Code 1', 'Code 2', 'Code 3', 'Code 4', 'Code 5', 'Code 6', 'Code 7', 'Code 8', 'Code 9', 'Code 10'])

# %%
teis_df['Date of Birth']=pd.to_datetime(teis_df['Date of Birth'])

# %%
teis_df['Age']=(pd.to_datetime(dt.date.today())-teis_df['Date of Birth'])

# %%
teis_df['Age']=teis_df['Age'].astype(str)
teis_df['Age']=teis_df['Age'].str.replace(' days', '')
teis_df['Age']=teis_df['Age'].astype(int)
teis_df['age_years']=round(teis_df['Age']/365, 0)

# %%
teis_df['age_years']
# Out:
# 0        1.0
# 1        3.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 23942    0.0
# 23943    3.0
# 23944    2.0
# 23945    4.0
# 23946    0.0
# Name: age_years, Length: 23947, dtype: float64

# %%
adp_null_score=teis_df.loc[teis_df['Adaptive-Personal Responsibility PR'].isnull()==True]
adp_null_score
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# 7        54937      F    2022-03-09    Southeast Tennessee
# ...        ...    ...           ...                    ...
# 23936  SP03281      F    2023-07-28          Memphis Delta
# 23937  SP03282      M    2023-02-06          Memphis Delta
# 23940  SP03285      M    2022-04-07        First Tennessee
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# ...

# %%
adp_score=teis_df.loc[teis_df['Adaptive-Personal Responsibility PR'].isnull()==False]
adp_score
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 1        47795      F    2020-12-23      Greater Nashville
# 5        54584      M    2020-06-05              Northwest
# 6        54861      F    2020-07-21          Memphis Delta
# 8        55077      F    2020-11-23        First Tennessee
# 11       55470      F    2021-05-15              Southwest
# ...        ...    ...           ...                    ...
# 23939  SP03284      M    2021-09-30        First Tennessee
# 23941  SP03286      F    2021-08-16          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23945  SP03290      M    2020-03-25          Memphis Delta
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 1      BDI-3 Eligibility Evaluation                           16.0
# 5      BDI-3 Eligibility Evaluation                           17.0
# ...

# %%
adp_score_1=adp_score[['Adaptive-Self Care PR']]
adp_score_1.corrwith(adp_score['Adaptive-Personal Responsibility PR'])
# Out:
# Adaptive-Self Care PR    0.486367
# dtype: float64

# %%
sns.boxplot(data=teis_df[['Adaptive-Personal Responsibility PR', 'Adaptive-Self Care PR']], orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=teis_df[['Communication-Expressive Communication PR', 'Communication-Receptive Communication PR']], orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=adp_score[['Adaptive-Personal Responsibility PR', 'Adaptive-Self Care PR']])
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=adp_score, x=adp_score['Adaptive-Self Care PR'], y=adp_score['age_years'], orient='h')
# Out:
# <AxesSubplot:xlabel='Adaptive-Self Care PR', ylabel='age_years'>

# %%
sns.violinplot(data=adp_null_score, x=adp_null_score['age_years'], y=adp_null_score['Adaptive-Self Care PR'])
# Out:
# <AxesSubplot:xlabel='age_years', ylabel='Adaptive-Self Care PR'>

# %%
adp_null_score['Adaptive-Self Care PR'].describe()
# Out:
# count    10802.000000
# mean        34.182744
# std         27.086896
# min          0.000000
# 25%          9.000000
# 50%         25.000000
# 75%         63.000000
# max         99.000000
# Name: Adaptive-Self Care PR, dtype: float64

# %%
adp_score['Adaptive-Self Care PR'].describe()
# Out:
# count    13138.000000
# mean        20.691582
# std         21.644526
# min          0.000000
# 25%          5.000000
# 50%         16.000000
# 75%         25.000000
# max         99.000000
# Name: Adaptive-Self Care PR, dtype: float64

# %%
sns.boxplot(data=teis_df, x=teis_df['Adaptive Percentile Rank'], y=teis_df['age_years'], orient='h', width=0.7)
# Out:
# <AxesSubplot:xlabel='Adaptive Percentile Rank', ylabel='age_years'>

# %%
sns.boxplot(data=teis_df, x=teis_df['Communication Percentile Rank'], y=teis_df['age_years'], orient='h', width=0.7)
# Out:
# <AxesSubplot:xlabel='Communication Percentile Rank', ylabel='age_years'>

# %%
sns.boxplot(data=teis_df, x=teis_df['Motor Percentile Rank'], y=teis_df['age_years'], orient='h', width=0.7)
# Out:
# <AxesSubplot:xlabel='Motor Percentile Rank', ylabel='age_years'>

# %%
sns.boxplot(data=teis_df, x=teis_df['Cognitive Percentile Rank'], y=teis_df['age_years'], orient='h', width=0.7)
# Out:
# <AxesSubplot:xlabel='Cognitive Percentile Rank', ylabel='age_years'>

# %%
sns.boxplot(data=teis_df, x=teis_df['Social-Emotional Percentile Rank'], y=teis_df['age_years'], orient='h', width=0.7)
# Out:
# <AxesSubplot:xlabel='Social-Emotional Percentile Rank', ylabel='age_years'>

# %%
sns.boxplot(data=teis_df, x=teis_df['Social-Emotional Percentile Rank'], y=teis_df['Program Label'], orient='h', width=0.7)
# Out:
# <AxesSubplot:xlabel='Social-Emotional Percentile Rank', ylabel='Program Label'>

# %%
sns.violinplot(data=teis_df, x=teis_df['Motor Percentile Rank'], y=teis_df['Program Label'], orient='h', width=0.7, inner='quart')
# Out:
# <AxesSubplot:xlabel='Motor Percentile Rank', ylabel='Program Label'>

# %%
sns.violinplot(data=teis_df, x=teis_df['Cognitive Percentile Rank'], y=teis_df['Program Label'], orient='h', width=0.7, inner='quart')
# Out:
# <AxesSubplot:xlabel='Cognitive Percentile Rank', ylabel='Program Label'>

# %%
sns.displot(data=teis_df[['Adaptive Percentile Rank', 'Cognitive Percentile Rank', 'Communication Percentile Rank', 'Social-Emotional Percentile Rank', 'Motor Percentile Rank']], kind='ecdf', height=7, aspect=1)

# %%
sns.displot(data=teis_df[['Adaptive-Self Care PR', 'Adaptive-Personal Responsibility PR']], kind='kde', height=7, aspect=1)

# %%
teis_df[['Adaptive-Self Care PR']].corrwith(teis_df['Adaptive-Personal Responsibility PR'])
# Out:
# Adaptive-Self Care PR    0.486367
# dtype: float64

# %%
sns.displot(data=teis_df[['Communication-Receptive Communication PR', 'Communication-Expressive Communication PR']], kind='kde', height=7, aspect=1)

# %%
teis_df[['Communication-Receptive Communication PR']].corrwith(teis_df['Communication-Expressive Communication PR'])
# Out:
# Communication-Receptive Communication PR    0.640678
# dtype: float64

# %%
sns.displot(data=teis_df[['Motor-Gross Motor PR', 'Motor-Fine Motor PR','Motor-Perceptual Motor PR']], kind='kde', height=7, aspect=1)

# %%
sns.displot(data=teis_df[['Cognitive-Attention and Memory PR', 'Cognitive-Reasoning / Academic Skills PR','Cognitive-Perception and Concepts PR']], kind='kde', height=7, aspect=1)
